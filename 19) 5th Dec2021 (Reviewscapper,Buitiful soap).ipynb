# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %% [markdown]
# ## step-1: Fetching the Data of Flipkart page
# here that data will be returned from flipkart site, which is shown when user type samsung

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"samsung" 
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=samsung'

# %%
uClient = uReq(flipkart_url)   #we are opening the url, ureq is python library
uClient

# %%
flipkartPage = uClient.read() #read data whatever present in the url(data present in Inspect)

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
flipkart_html = bs(flipkartPage, "html.parser") #it beautity the above data
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Step 2:- Selecting a product

# %%
bigboxes = flipkart_html.findAll("div", {"class": "_1AtVbE col-12-12"})
bigboxes
# Out:
# [<div class="_1AtVbE col-12-12" style="padding:0px 0px 10px 0px"><a class="UYS4aW _3E_YdP" href="/samsung-galaxy-f42-5g-matte-aqua-128-gb/p/itme9cf5fd993f7c?pid=MOBG6WRA5UHQK9EZ&amp;otracker=sp_browse_announcement_search.flipkart.com"><div class="_3ywSr_" style="padding-top:53.57%"><div class="_1bEAQy _312yBx" style="padding-top:53.57%"><img alt="Samsung F42 5G" class="_2OHU_q _2WCh1J"/><img alt="Samsung F42 5G" class="kJjFO0 _3DIhEh _9JTfqZ" src="https://rukminim1.flixcart.com/flap/100/54/image/0fef3e5f60f5c37e.jpg?q=50"/></div></div><div class="_1sPNy4"><div class="_2LR_KO">#FullOnLegend Galaxy F42 5G</div><div class="tMzY0d">From ₹20,999 | 64MP Cam | Sale is ON!</div></div></a></div>,
# ...

# %%
len(bigboxes)   #this tells number of product in each bigbox
# Out:
# 31

# %%
bigboxes[0]
# Out:
# <div class="_1AtVbE col-12-12" style="padding:0px 0px 10px 0px"><a class="UYS4aW _3E_YdP" href="/samsung-galaxy-f42-5g-matte-aqua-128-gb/p/itme9cf5fd993f7c?pid=MOBG6WRA5UHQK9EZ&amp;otracker=sp_browse_announcement_search.flipkart.com"><div class="_3ywSr_" style="padding-top:53.57%"><div class="_1bEAQy _312yBx" style="padding-top:53.57%"><img alt="Samsung F42 5G" class="_2OHU_q _2WCh1J"/><img alt="Samsung F42 5G" class="kJjFO0 _3DIhEh _9JTfqZ" src="https://rukminim1.flixcart.com/flap/100/54/image/0fef3e5f60f5c37e.jpg?q=50"/></div></div><div class="_1sPNy4"><div class="_2LR_KO">#FullOnLegend Galaxy F42 5G</div><div class="tMzY0d">From ₹20,999 | 64MP Cam | Sale is ON!</div></div></a></div>

# %%
box = bigboxes[20]
box.div.div.div.a['href']
# Out:
# '/samsung-galaxy-a22-5g-gray-128-gb/p/itmec5c318d07f46?pid=MOBG54F2RKZH9FNZ&lid=LSTMOBG54F2RKZH9FNZEOPQVU&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_18&otracker=search&fm=organic&iid=f902d3cd-0da6-496b-939d-989221702bfa.MOBG54F2RKZH9FNZ.SEARCH&ppt=None&ppn=None&ssid=pohtlgg7tc0000001641377047298&qH=fe546279a62683de'

# %%
url_mobile = "https://www.flipkart.com"+box.div.div.div.a['href']
url_mobile
# Out:
# 'https://www.flipkart.com/samsung-galaxy-m11-black-64-gb/p/itm2b3e5356a5b97?pid=MOBFRZZH4HHGU6YT&lid=LSTMOBFRZZH4HHGU6YTP0UK7J&marketplace=FLIPKART&q=samsung&store=tyy%2F4io&srno=s_1_18&otracker=search&fm=organic&iid=d1aaf0fe-7ce0-48d4-b88b-a231059b98a0.MOBFRZZH4HHGU6YT.SEARCH&ppt=None&ppn=None&ssid=7s5kio3wq80000001641376656650&qH=fe546279a62683de'

# %% [markdown]
# ## Step 3:- Fetch all the info of the selected product
# in this case we have selected samsung galaxy M32

# %%
#uClient_mobile = uReq(url_mobile)   done above
#or
prodRes = requests.get(url_mobile)
prodRes
# Out:
# <Response [200]>

# %%
prod_html = bs(prodRes.text, "html.parser") #passing the feched info in buitiful soap(for buitifying or organizing data)
prod_html                                   # "html.parser" to travel/parse in HTML format
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Step 4:- Selecting a particular review of the product

# %%
#commentboxes = prod_html.find_all('div', {'class': "_3nrCtb"})
prod_html.find_all('div', {'class': "_3nrCtb"})
# Out:
# []

# %%
review = prod_html.find_all('div', {'class': "_16PBlm"})
review
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Super!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Good one. I bought it in the lockdown they deliver as the said. This phone overall performance is super for this cost. This is miracle to get such a branded one from flipcart. Thanks to flipcart.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">karikalan mathialagan</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-cdc1115b-96e5-42f4-935b-e045e1c8c04a"><span>Certified Buyer</span><span>, Coimbatore</span></p><div></div><p class="_2sc7Z
# ...

# %%
len(review)
# Out:
# 11

# %%
review[0]
# Out:
# <div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Super!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Good one. I bought it in the lockdown they deliver as the said. This phone overall performance is super for this cost. This is miracle to get such a branded one from flipcart. Thanks to flipcart.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">karikalan mathialagan</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" width="14" xmlns="http://www.w3.org/2000/svg"><g><circle cx="6" cy="6" fill="#878787" r="6"></circle><path d="M3 6l2 2 4-4" fill="#878787" stroke="#FFF" stroke-width="1.5"></path></g></svg><p class="_2mcZGG" id="review-cdc1115b-96e5-42f4-935b-e045e1c8c04a"><span>Certified Buyer</span><span>, Coimbatore</span></p><div></div><p class="_2sc7ZR
# ...

# %%
commentbox = review[0]
commentbox.div.div.find_all('p',{'class': '_2sc7ZR _2V5EHH'})
# Out:
# []

# %% [markdown]
# #### Ratings=>

# %%
ratings = commentbox.div.div.div.div.text #this will give rating
ratings
# Out:
# '5'

# %% [markdown]
# #### Heading of comment=>

# %%
comment_head = commentbox.div.div.div.p.text
comment_head
# Out:
# 'Super!'

# %% [markdown]
# #### Comments=>

# %%
comtag = commentbox.div.div.find_all('div', {'class': ''})
custComment = comtag[0].div.text
custComment
# Out:
# 'Good one. I bought it in the lockdown they deliver as the said. This phone overall performance is super for this cost. This is miracle to get such a branded one from flipcart. Thanks to flipcart.'

# %%
# Did on my own

#imports
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# SEEING ALL MOBILES in flipkart page
#Setting up flipkart url for seatching 'samsung'
flipkart_url = "https://www.flipkart.com/search?q="+"samsung"

#Opening the url
uClient = uReq(flipkart_url)

#Reading data of the opened url
flipkartPage = uClient.read()

#Beautifying the page in form of HTML page
flipkart_html = bs(flipkartPage, "html.parser")

#Selecting all the bigbox of the page
bigboxes = flipkart_html.findAll("div", {"class": "_2kHMtA"})

#choosing bigbox at index Zero
bigboxes[0] 

#Selecting the url inside the bigbox which will get triggered when we click on a particular mobile
bigboxes[0].a['href']


#__________________________________________________________________________________________________________
# SEEING PARTICULAR MOBILES in flipkart page
url_mobile = "https://www.flipkart.com"+bigboxes[0].a['href'] #Creating a new url for the product page
prodRes = requests.get(url_mobile)       #Opening the new url
prod_html = bs(prodRes.text, "html.parser") #Beautifying the page in form of HTML page
bigboxes_of_Reviews = prod_html.find_all('div', {'class': "col _2wzgFH"}) #Selecting bigbox for all reviews

#Selecting bigbox for a particular review
bigboxes_of_Reviews[0]



#XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
#Printing Rating
print( bigboxes_of_Reviews[0].div.div.text )

#Printing Heading of the review

print(bigboxes_of_Reviews[0].div.p.text)  #'p' since class has syntax as-> <p class>......

#Printing the review
comtag = bigboxes_of_Reviews[0].find_all('div', {'class': ''}) #Selecting class which contains Review, since no name for 
print( comtag[0].div.text )                             # the class containg review, herefore leave empty
# Out:
# 4
# Value-for-money
# Nice battery backup, good camera and also a good display. For daily use phone is smooth and perfect.

# %%
# Did on my own

#imports
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# SEEING ALL MOBILES in flipkart page
#Setting up flipkart url for seatching 'samsung'
flipkart_url = "https://www.flipkart.com/search?q="+"samsung"

#Opening the url
uClient = uReq(flipkart_url)

#Reading data of the opened url
flipkartPage = uClient.read()

#Beautifying the page in form of HTML page
flipkart_html = bs(flipkartPage, "html.parser")

#Selecting all the bigbox of the page
bigboxes = flipkart_html.findAll("div", {"class": "_2kHMtA"})

#choosing bigbox at index Zero
bigboxes[0] 

#Selecting the url inside the bigbox which will get triggered when we click on a particular mobile
bigboxes[0].a['href']


#__________________________________________________________________________________________________________
# SEEING PARTICULAR MOBILES in flipkart page
url_mobile = "https://www.flipkart.com"+bigboxes[0].a['href'] #Creating a new url for the product page
prodRes = requests.get(url_mobile)       #Opening the new url
prod_html = bs(prodRes.text, "html.parser") #Beautifying the page in form of HTML page
bigboxes_of_Reviews = prod_html.find_all('div', {'class': "col _2wzgFH"}) #Selecting bigbox for all reviews

#Selecting bigbox for a particular review
num_of_reviews = int(input("How many reviews you want?"))
for i in range(num_of_reviews):  
    print("Review->",i)
    bigboxes_of_Reviews[i]



    #XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
    #Printing Rating
    print( bigboxes_of_Reviews[i].div.div.text )

    #Printing Heading of the review
    print(bigboxes_of_Reviews[i].div.p.text)  #'p' since class has syntax as-> <p class>......

    #Printing the review
    comtag = bigboxes_of_Reviews[i].find_all('div', {'class': ''}) #Selecting class which contains Review, since no name for 
                                                                # the class containg review, herefore leave empty
    print( comtag[0].div.text ) #Here we have done index 0 becaue there will be single review in a bigbox                            
    print('\n\n')
# Out:
# How many reviews you want?5
# Review-> 0
# 4
# Value-for-money
# Nice battery backup, good camera and also a good display. For daily use phone is smooth and perfect.
#
#
#
# Review-> 1
# 4
# Wonderful
# I got the product at my door step in 16 hours after ordering so thank you flipkart for this excellent delivery. I have used it for 3 days and now writing my review:Pro:1. Battery is brilliant and perfect for people who spent lot of time on multimedia2. Display 90hrz is very smooth and good looking. Didn't feel the absence of Full HD actually better than full HD IPS displays.3. Samsung One UI 4. Look & feel. Very comfortable to hold. Background Matt finish no fingerprint5. Primary camera...
#
#
#
# Review-> 2
# 4
# Good choice
# Good product in this price segment....looks like a premium smartphone.... performance is up to the mark ..... according to me , this device is perfect for the students who are doing the online classes.....don't expect high from camera or performance....
#
#
#
# ...
